# %% [markdown]
# **Demo Notebook**
#
# Shows example of launching inference and evaluation pipelines on sample dataset. You can put the link to your own dataset.

# %%
import os
os.environ['DATASET_LINK'] = "https://disk.360.yandex.ru/d/egfGDP3qyqreLg" # PUT YOUR DATASET LINK HERE

# %% [markdown]
# **Inference**

# %% [markdown]
# 1. Clone GitHub repository

# %%
# !git clone https://github.com/ayazvaliev/hifigan_hw.git

# %% [markdown]
# 2. Change CWD to root directory of repo

# %%
os.chdir('hifigan_hw')

# %% [markdown]
# Also make sure you're on the main branch

# %%
# !git checkout main

# %% [markdown]
# 3. Install all necessary modules from requirements.txt

# %%
# !pip install -r requirements.txt -qqq

# %% [markdown]
# 4. Load checkpoint using load_checkpoint.py script (training logs and configs of the training setups are included)

# %%
# !python load_checkpoint.py --help

# %%
# !python load_checkpoint.py --output_dir YOUR_CKPT_SAVE_DIR

# %% [markdown]
# 5. Run synthesize.py. Pass all necessary options to script as follows

# %%
# !python synthesize.py 'dataset_url="${oc.env:DATASET_LINK}"' inferencer.from_pretrained='YOUR_CKPT_SAVE_DIR/checkpoint-epoch260_gen.pth' 'inferencer.save_path="YOUR_PRED_SAVE_DIR"' data_root="YOUR_DATASET_SAVE_DIR"

# %% [markdown]
# If you want to run on a single prompt, you can specify it in command line:

# %%
# !python synthesize.pt prompt="Some sample text" inferencer.from_pretrained='YOUR_CKPT_SAVE_DIR/checkpoint-epoch260_gen.pth' 'inferencer.save_path="YOUR_PRED_SAVE_DIR"'
